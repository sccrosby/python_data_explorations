# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fname = '../offline_data/hotel_bookings.csv'

df = pd.read_csv(fname)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
print(df.keys())
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df_n = df.select_dtypes(include=numerics)

# %%
for key in df.keys():
    print(df[key].unique())
# Out:
# ['Resort Hotel' 'City Hotel']
# [0 1]
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
#  172 171 145 121 178 305 173 152 354 347 158 185 349 183 352 177 200 192
# ...

# %%
plt.hist(df['lead_time'])
# Out:
# (array([6.1639e+04, 2.4403e+04, 1.6345e+04, 8.6580e+03, 5.2650e+03,
#         1.8250e+03, 8.4400e+02, 2.4700e+02, 1.6200e+02, 2.0000e+00]),
#  array([  0. ,  73.7, 147.4, 221.1, 294.8, 368.5, 442.2, 515.9, 589.6,
#         663.3, 737. ]),
#  <BarContainer object of 10 artists>)

# %%
for key in df.keys():
    pm = sum(df[key].isnull()) / len(df[key])
    print('{:s} missing {:4.4f}\%'.format(key,pm*100))
# Out:
# hotel missing 0.0000\%
# is_canceled missing 0.0000\%
# lead_time missing 0.0000\%
# arrival_date_year missing 0.0000\%
# arrival_date_month missing 0.0000\%
# arrival_date_week_number missing 0.0000\%
# arrival_date_day_of_month missing 0.0000\%
# stays_in_weekend_nights missing 0.0000\%
# stays_in_week_nights missing 0.0000\%
# adults missing 0.0000\%
# children missing 0.0034\%
# babies missing 0.0000\%
# meal missing 0.0000\%
# country missing 0.4087\%
# market_segment missing 0.0000\%
# distribution_channel missing 0.0000\%
# is_repeated_guest missing 0.0000\%
# previous_cancellations missing 0.0000\%
# previous_bookings_not_canceled missing 0.0000\%
# reserved_room_type missing 0.0000\%
# assigned_room_type missing 0.0000\%
# booking_changes missing 0.0000\%
# deposit_type missing 0.0000\%
# agent missing 13.6862\%
# company missing 94.3069\%
# days_in_waiting_list missing 0.0000\%
# customer_type missing 0.0000\%
# adr missing 0.0000\%
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
s = df.groupby('arrival_date_month').sum()
c = df.groupby('arrival_date_month').count()

# %%
plt.plot(s['is_canceled']/c['is_canceled'])

# %%
df.groupby('is_repeated_guest').mean()
# Out:
#                    is_canceled   lead_time  arrival_date_year  \
# is_repeated_guest
# 0                     0.377851  106.425221        2016.155226
# 1                     0.144882   30.786352        2016.196850
#
#                    arrival_date_week_number  arrival_date_day_of_month  \
# is_repeated_guest
# 0                                 27.239600                  15.808038
# 1                                 24.907349                  15.501050
#
#                    stays_in_weekend_nights  stays_in_week_nights    adults  \
# is_repeated_guest
# 0                                 0.943416              2.533994  1.871803
# 1                                 0.447769              1.478215  1.389239
#
#                    children    babies  previous_cancellations  \
# is_repeated_guest
# 0                  0.106268  0.008107                0.074503
# 1                  0.031759  0.003150                0.469816
#
# ...

# %% [markdown]
# Looks like regulars cancel much less

# %%
df.pivot_table('hotel', index=['is_canceled'], columns=['is_repeated_guest'], aggfunc='count')
# Out:
# is_repeated_guest      0     1
# is_canceled
# 0                  71908  3258
# 1                  43672   552

# %%
df.pivot_table('previous_cancellations', index=['is_canceled'], columns=['is_repeated_guest'], aggfunc='mean')
# Out:
# is_repeated_guest         0         1
# is_canceled
# 0                  0.001349  0.334561
# 1                  0.194953  1.268116

# %% [markdown]
# ## Try to predict cancellation
# Using lead_time, arrival_date_month, adults, children, babies, previous cancellations, previous_bookings_not_canceled

# %%
# select and remove NaN rows
X = df[['lead_time', 'adults', 'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled','is_canceled','arrival_date_month']]
X = X.dropna(axis=0)
X.shape

# select y
y = X['is_canceled']

# Drop y from X
X = X.drop('is_canceled',axis=1)

# select month
X_month = X['arrival_date_month']
X = X.drop('arrival_date_month',axis=1)

# Convert to numpy
X = X.to_numpy()

# %%
y.shape
# Out:
# (119386,)

# %%
X.shape
# Out:
# (119386, 6)

# %%
# Do one-hot encoding for month
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')

X_enc = X_month.to_numpy().reshape(-1, 1)

enc.fit(X_enc)
X_enc = enc.transform(X_enc)

# %%
print(X.shape)
print(X_enc.shape)
# Out:
# (119386, 6)
# (119386, 12)

# %%
Xm = np.concatenate((X,X_enc.todense()),axis=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline

X_train, X_test, y_train, y_test = train_test_split(Xm,y)

pipeline = Pipeline([
    ("scalar", StandardScaler()),
    ("log_reg", LogisticRegression())
])

cross_val_score(pipeline, X_train, y_train, cv=3, scoring="accuracy")
# Out:
# array([0.68918149, 0.68682571, 0.69081284])

# %%
scalar = StandardScaler()
X_train_tr = scalar.fit_transform(X_train)
X_test_tr = scalar.transform(X_test)

clf_log = LogisticRegression()
clf_log.fit(X_train_tr,y_train)

pred = clf_log.predict(X_test_tr)

from sklearn.metrics import precision_score, recall_score
ps = precision_score(y_test,pred)
rs = recall_score(y_test,pred)

print(ps, rs)

# Of identified cancellations, 70% are correct.  (precision)
# Of all true cancellations, 30% are identified. (recall)
# Out:
# 0.6921470342522974 0.29939470593549555

# %%
clf_log.coef_
clf_log.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import precision_recall_curve

y_scores = cross_val_predict(clf_log, X_train_tr, y_train, cv=3, method='decision_function')

precisions, recalls, thresholds = precision_recall_curve(y_train, y_scores)

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], 'b--', label='Precision')
    plt.plot(thresholds, recalls[:-1], 'g-',label='Recall')
    plt.legend()

plot_precision_recall_vs_threshold(precisions,recalls,thresholds)
plt.grid()
plt.xlim((-2,2))
plt.show()

# %%
y_scores = cross_val_predict(RandomForestClassifier(), X_train_tr, y_train, cv=3, method='predict_proba')

precisions, recalls, thresholds = precision_recall_curve(y_train, y_scores[:,1])

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], 'b--', label='Precision')
    plt.plot(thresholds, recalls[:-1], 'g-',label='Recall')
    plt.legend()

plot_precision_recall_vs_threshold(precisions,recalls,thresholds)
plt.grid()
plt.show()

# %%
from sklearn.neural_network import MLPClassifier

y_scores = cross_val_predict(MLPClassifier(), X_train_tr, y_train, cv=3, method='predict_proba')

precisions, recalls, thresholds = precision_recall_curve(y_train, y_scores[:,1])

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], 'b--', label='Precision')
    plt.plot(thresholds, recalls[:-1], 'g-',label='Recall')
    plt.legend()

plot_precision_recall_vs_threshold(precisions,recalls,thresholds)
plt.grid()
plt.show()

# %%
from sklearn.ensemble import ExtraTreesClassifier

y_scores = cross_val_predict(ExtraTreesClassifier(), X_train_tr, y_train, cv=3, method='predict_proba')

precisions, recalls, thresholds = precision_recall_curve(y_train, y_scores[:,1])

def plot_precision_recall_vs_threshold(precisions, recalls, thresholds):
    plt.plot(thresholds, precisions[:-1], 'b--', label='Precision')
    plt.plot(thresholds, recalls[:-1], 'g-',label='Recall')
    plt.legend()

plot_precision_recall_vs_threshold(precisions,recalls,thresholds)
plt.grid()
plt.show()

# %%
y_scores_log = cross_val_predict(clf_log, X_train_tr, y_train, cv=3, method='decision_function')
y_scores_for = cross_val_predict(RandomForestClassifier(), X_train_tr, y_train, cv=3, method='predict_proba')

from sklearn.metrics import roc_curve
fpr1, tpr1, thresholds1 = roc_curve(y_train, y_scores_log)
fpr2, tpr2, thresholds2 = roc_curve(y_train, y_scores_for[:,1])
plt.plot(fpr1,tpr1,label='Logistic')
plt.plot(fpr2,tpr2,label='Rnd Forest')
plt.ylabel('True Positive Rate (Recall)')
plt.xlabel('False Positive Rate')
plt.title('ROC')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Which features are useful?

# %%
### scalar = StandardScaler()
X_train_tr = scalar.fit_transform(X_train)
X_test_tr = scalar.transform(X_test)

N = 12

clf_log = LogisticRegression(penalty='l1',solver='liblinear')
clf_log.fit(X_train_tr[:,:N],y_train)

pred = clf_log.predict(X_test_tr[:,:N])

from sklearn.metrics import precision_score, recall_score
ps = precision_score(y_test,pred)
rs = recall_score(y_test,pred)

print(ps, rs)
# Out:
# 0.6918011894647409 0.2942451892673232

# %%
labs = ['lead_time', 'adults', 'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled']
for i in range(6):
    print('{:s}  {:4.1e}'.format(labs[i],clf_log.coef_[0][i]))
# Out:
# lead_time  5.2e-01
# adults  6.8e-02
# children  5.4e-02
# babies  -7.7e-02
# previous_cancellations  2.4e+00
# previous_bookings_not_canceled  -1.2e+00

# %%
plt.plot(clf_log.coef_[0])
plt.grid()

# %%
clf_log.coef_[0][0]
# Out:
# 0.5379011965816136

# %%
from sklearn.ensemble import RandomForestClassifier

pipeline = Pipeline([
    ("scalar", StandardScaler()),
    ("clf_for", RandomForestClassifier())
])
cross_val_score(pipeline, X_train, y_train, cv=3, scoring="accuracy")
# Out:
# array([0.74107951, 0.74790592, 0.74874355])

# %%
from sklearn.metrics import precision_score, recall_score



ps = precision_score(y_test_5,y_test_5_predict)
rs = recall_score(y_test_5,y_test_5_predict)

# %%
# Search for best random forest
from sklearn.model_selection import GridSearchCV

param_grid = dict(n_estimators=[50, 100, 200])
grid_clf = GridSearchCV(RandomForestClassifier(), param_grid, cv=3, verbose=2)
grid_clf.fit(X_train_tr, y_train)
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END ....................................n_estimators=50; total time=   1.8s
# [CV] END ....................................n_estimators=50; total time=   1.8s
# [CV] END ....................................n_estimators=50; total time=   1.8s
# [CV] END ...................................n_estimators=100; total time=   3.7s
# [CV] END ...................................n_estimators=100; total time=   3.8s
# [CV] END ...................................n_estimators=100; total time=   3.8s
# [CV] END ...................................n_estimators=200; total time=   7.6s
# [CV] END ...................................n_estimators=200; total time=   7.6s
# [CV] END ...................................n_estimators=200; total time=   7.6s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [50, 100, 200]}, verbose=2)

# %%
grid_clf.best_params_
# Out:
# {'n_estimators': 200}

# %%
grid_clf.best_score_
# Out:
# 0.7446363915296267

# %%
grid_clf.cv_results_
# Out:
# {'mean_fit_time': array([1.7087245 , 3.40610623, 6.81088297]),
#  'std_fit_time': array([0.01020659, 0.02774039, 0.012817  ]),
#  'mean_score_time': array([0.22671453, 0.45376968, 0.89953828]),
#  'std_score_time': array([0.00170328, 0.00262536, 0.00579522]),
#  'param_n_estimators': masked_array(data=[50, 100, 200],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 50},
#   {'n_estimators': 100},
#   {'n_estimators': 200}],
#  'split0_test_score': array([0.74506651, 0.7458036 , 0.74677522]),
#  'split1_test_score': array([0.74512497, 0.74542652, 0.745259  ]),
#  'split2_test_score': array([0.74130537, 0.74200898, 0.74187496]),
#  'mean_test_score': array([0.74383228, 0.74441303, 0.74463639]),
#  'std_test_score': array([0.00178696, 0.00170688, 0.00204839]),
#  'rank_test_score': array([3, 2, 1])}

# %%
cross_val_score(RandomForestClassifier(min_samples_split=0.01), X_train, y_train, cv=3, scoring="accuracy")
# Out:
# array([0.71692297, 0.7176171 , 0.71808618])
